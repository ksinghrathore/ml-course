# %%
! pwd
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20210118144834-0000
# KERNEL_ID = 8eeb153d-3769-4190-a9c3-561ba6422378
# /home/spark/shared
